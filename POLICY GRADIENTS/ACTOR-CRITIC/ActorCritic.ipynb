# %%
import math
import random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
import import_ipynb
import multiprocessing_env
# Out:
# importing Jupyter notebook from multiprocessing_env.ipynb

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
env_name = "CartPole-v0"
env = gym.make(env_name)
# Out:
# /home/iyer/gym/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class Actor(nn.Module):
    def __init__(self, input_dims,n_actions, h1, h2,lr):
        super(Actor,self).__init__()
        self.input_dims = input_dims
        self.lr = lr
        self.h1 = h1
        self.h2 = h2
        self.n_actions = n_actions
        self.linear1 = nn.Linear(*self.input_dims, self.h1)
        self.linear2 = nn.Linear(self.h1, self.h2)
        self.linear3 = nn.Linear(self.h2, self.n_actions)

    def forward(self,obs):
        x = torch.tensor(obs,dtype=torch.float)
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = self.linear3(x)

        return x

# %%
class Critic(nn.Module):
    def __init__(self,input_dims,h1,h2,lr):
        super(Critic,self).__init__()
        self.lr=lr
        self.h1=h1
        self.h2=h2
        self.linear1=nn.Linear(input_dims,self.h1)
        self.linear2=nn.Linear(self.h1,self.h2)
        self.linear3=nn.Linear(self.h2,1)
        
    def forward(self,state):
        x=torch.FloatTensor(state)
        x=F.relu(self.linear1(x))
        x=F.relu(self.linear2(x))
        x=self.linear3(x)
        
        return x

# %%
def plot(rewards):
    score = np.array(rewards)
    iters = np.arange(len(rewards))
    plt.plot(iters,score)
    plt.xlabel('training iterations')
    plt.ylabel('Total rewards')
    plt.show()

# %%
def compute_returns(next_value, rewards, masks, gamma=0.99):
    R = next_value
    returns = []
    for step in reversed(range(len(rewards))):
        R = rewards[step] + gamma * R * masks[step]
        returns.insert(0, R)
    return returns

# %%
input_dims  = env.observation_space.shape[0]
n_actions = env.action_space.n

#Hyper params:
Actor = Actor([input_dims],n_actions,h1=64,h2=16,lr=0.001)
optimizerA = optim.Adam(Actor.parameters())
Critic=Critic(input_dims,h1=64,h2=16,lr=0.001)
optimizerC=optim.Adam(Critic.parameters())

# %%
num_episodes   = 1000
def test_env(vis=False):
    state = env.reset()
    if vis: env.render()
    done = False
    total_reward = 0
    while not done:
        state = torch.FloatTensor(state).unsqueeze(0)
        dist, _ = model(state)
        next_state, reward, done, _ = env.step(dist.sample().cpu().numpy()[0])
        state = next_state
        if vis: env.render()
        total_reward += reward
    return total_reward

# %%
total_return=0
return_list = []
for  i in range(num_episodes):
    print('episode: ', i, 'reward %.2f' %total_return )
    total_return=0
    log_probs = []
    values    = []
    reward_list= []
    masks     = []
    entropy = 0
    done=False
    state = env.reset()
    while not done:
        state = torch.FloatTensor(state)
        value=Critic(state)
        X=Actor(state)
        probs=F.softmax(X)
        dist=Categorical(probs)
        action = dist.sample()
        next_state, reward, done, _ = env.step(action.item())
        log_probs.append(dist.log_prob(action))
        values.append(value)
        reward_list.append(reward)
        masks.append((1 - done))
        entropy+=dist.entropy().mean()
        state = next_state
        next_state = torch.FloatTensor(next_state)
        next_value = Critic(next_state)
        state = next_state
        total_return+=reward
    return_list.append(total_return)
    returns = compute_returns(next_value, reward_list, masks)
    advantage=[]
    for r,v in zip(returns,values):
        advantage.append(r-v)
    actor_loss=0
    critic_loss=0
    loss=0
    for g,log_prob in zip(advantage,log_probs):
        actor_loss+=-g*log_prob
        critic_loss+= g.pow(2)
    loss = actor_loss + 0.5 * critic_loss - 0.001 * entropy
    optimizerA.zero_grad()
    optimizerC.zero_grad()
    loss.backward()
    optimizerA.step()
    optimizerC.step()

plot(return_list)
# Out:
# episode:  0 reward 0.00
# episode:  1 reward 15.00
# episode:  2 reward 22.00
# episode:  3 reward 15.00
# episode:  4 reward 17.00
# episode:  5 reward 13.00
# episode:  6 reward 10.00
# episode:  7 reward 12.00
# episode:  8 reward 10.00
# episode:  9 reward 18.00
# /home/iyer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /home/iyer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# episode:  10 reward 26.00
# episode:  11 reward 30.00
# episode:  12 reward 14.00
# episode:  13 reward 18.00
# episode:  14 reward 20.00
# episode:  15 reward 14.00
# episode:  16 reward 17.00
# episode:  17 reward 19.00
# episode:  18 reward 15.00
# episode:  19 reward 19.00
# episode:  20 reward 13.00
# episode:  21 reward 13.00
# episode:  22 reward 10.00
# episode:  23 reward 16.00
# episode:  24 reward 17.00
# episode:  25 reward 18.00
# episode:  26 reward 34.00
# episode:  27 reward 31.00
# episode:  28 reward 13.00
# episode:  29 reward 36.00
# episode:  30 reward 15.00
# episode:  31 reward 25.00
# episode:  32 reward 23.00
# episode:  33 reward 26.00
# episode:  34 reward 14.00
# episode:  35 reward 15.00
# episode:  36 reward 32.00
# episode:  37 reward 13.00
# episode:  38 reward 47.00
# episode:  39 reward 12.00
# episode:  40 reward 19.00
# episode:  41 reward 17.00
# episode:  42 reward 29.00
# episode:  43 reward 23.00
# episode:  44 reward 22.00
# episode:  45 reward 28.00
# episode:  46 reward 14.00
# episode:  47 reward 17.00
# episode:  48 reward 22.00
# episode:  49 reward 18.00
# episode:  50 reward 24.00
# episode:  51 reward 27.00
# episode:  52 reward 12.00
# episode:  53 reward 18.00
# episode:  54 reward 11.00
# episode:  55 reward 12.00
# episode:  56 reward 23.00
# episode:  57 reward 21.00
# episode:  58 reward 26.00
# episode:  59 reward 19.00
# episode:  60 reward 11.00
# episode:  61 reward 20.00
# episode:  62 reward 19.00
# episode:  63 reward 13.00
# episode:  64 reward 23.00
# episode:  65 reward 13.00
# episode:  66 reward 27.00
# episode:  67 reward 10.00
# episode:  68 reward 12.00
# episode:  69 reward 17.00
# episode:  70 reward 13.00
# episode:  71 reward 25.00
# episode:  72 reward 25.00
# episode:  73 reward 28.00
# episode:  74 reward 13.00
# episode:  75 reward 115.00
# episode:  76 reward 14.00
# episode:  77 reward 39.00
# episode:  78 reward 38.00
# episode:  79 reward 15.00
# episode:  80 reward 13.00
# episode:  81 reward 24.00
# episode:  82 reward 46.00
# episode:  83 reward 24.00
# episode:  84 reward 15.00
# episode:  85 reward 32.00
# episode:  86 reward 35.00
# episode:  87 reward 53.00
# episode:  88 reward 49.00
# episode:  89 reward 42.00
# episode:  90 reward 39.00
# episode:  91 reward 58.00
# episode:  92 reward 18.00
# episode:  93 reward 24.00
# episode:  94 reward 69.00
# episode:  95 reward 13.00
# episode:  96 reward 36.00
# episode:  97 reward 23.00
# episode:  98 reward 29.00
# episode:  99 reward 19.00
# episode:  100 reward 46.00
# episode:  101 reward 57.00
# episode:  102 reward 39.00
# episode:  103 reward 60.00
# episode:  104 reward 40.00
# episode:  105 reward 29.00
# episode:  106 reward 23.00
# episode:  107 reward 72.00
# episode:  108 reward 35.00
# episode:  109 reward 43.00
# episode:  110 reward 144.00
# episode:  111 reward 16.00
# episode:  112 reward 26.00
# episode:  113 reward 38.00
# episode:  114 reward 64.00
# episode:  115 reward 81.00
# episode:  116 reward 32.00
# episode:  117 reward 25.00
# episode:  118 reward 35.00
# episode:  119 reward 43.00
# episode:  120 reward 44.00
# episode:  121 reward 66.00
# episode:  122 reward 44.00
# episode:  123 reward 82.00
# episode:  124 reward 65.00
# episode:  125 reward 45.00
# episode:  126 reward 15.00
# episode:  127 reward 98.00
# episode:  128 reward 144.00
# episode:  129 reward 28.00
# episode:  130 reward 60.00
# episode:  131 reward 68.00
# episode:  132 reward 114.00
# episode:  133 reward 27.00
# episode:  134 reward 132.00
# episode:  135 reward 32.00
# episode:  136 reward 109.00
# episode:  137 reward 106.00
# episode:  138 reward 64.00
# episode:  139 reward 50.00
# episode:  140 reward 87.00
# episode:  141 reward 68.00
# episode:  142 reward 51.00
# episode:  143 reward 27.00
# episode:  144 reward 50.00
# episode:  145 reward 122.00
# episode:  146 reward 61.00
# episode:  147 reward 75.00
# episode:  148 reward 156.00
# episode:  149 reward 188.00
# episode:  150 reward 35.00
# episode:  151 reward 138.00
# episode:  152 reward 200.00
# episode:  153 reward 18.00
# episode:  154 reward 78.00
# episode:  155 reward 128.00
# episode:  156 reward 128.00
# episode:  157 reward 107.00
# episode:  158 reward 111.00
# episode:  159 reward 118.00
# episode:  160 reward 130.00
# episode:  161 reward 60.00
# episode:  162 reward 58.00
# episode:  163 reward 69.00
# episode:  164 reward 86.00
# episode:  165 reward 151.00
# episode:  166 reward 43.00
# episode:  167 reward 31.00
# episode:  168 reward 49.00
# episode:  169 reward 132.00
# episode:  170 reward 152.00
# episode:  171 reward 95.00
# episode:  172 reward 76.00
# episode:  173 reward 120.00
# episode:  174 reward 59.00
# episode:  175 reward 200.00
# episode:  176 reward 48.00
# episode:  177 reward 129.00
# episode:  178 reward 74.00
# episode:  179 reward 99.00
# episode:  180 reward 95.00
# episode:  181 reward 75.00
# episode:  182 reward 152.00
# episode:  183 reward 136.00
# episode:  184 reward 200.00
# episode:  185 reward 119.00
# episode:  186 reward 181.00
# episode:  187 reward 72.00
# episode:  188 reward 83.00
# episode:  189 reward 57.00
# episode:  190 reward 127.00
# episode:  191 reward 67.00
# episode:  192 reward 97.00
# episode:  193 reward 100.00
# episode:  194 reward 86.00
# episode:  195 reward 164.00
# episode:  196 reward 68.00
# episode:  197 reward 119.00
# episode:  198 reward 173.00
# episode:  199 reward 135.00
# episode:  200 reward 46.00
# episode:  201 reward 200.00
# episode:  202 reward 200.00
# episode:  203 reward 99.00
# episode:  204 reward 53.00
# episode:  205 reward 200.00
# episode:  206 reward 61.00
# episode:  207 reward 125.00
# episode:  208 reward 115.00
# episode:  209 reward 78.00
# episode:  210 reward 106.00
# episode:  211 reward 109.00
# episode:  212 reward 131.00
# episode:  213 reward 35.00
# episode:  214 reward 200.00
# episode:  215 reward 112.00
# episode:  216 reward 161.00
# episode:  217 reward 158.00
# episode:  218 reward 142.00
# episode:  219 reward 200.00
# episode:  220 reward 106.00
# episode:  221 reward 144.00
# episode:  222 reward 112.00
# episode:  223 reward 158.00
# episode:  224 reward 117.00
# episode:  225 reward 200.00
# episode:  226 reward 45.00
# episode:  227 reward 104.00
# episode:  228 reward 200.00
# episode:  229 reward 143.00
# episode:  230 reward 119.00
# episode:  231 reward 177.00
# episode:  232 reward 200.00
# episode:  233 reward 167.00
# episode:  234 reward 188.00
# episode:  235 reward 165.00
# episode:  236 reward 200.00
# episode:  237 reward 146.00
# episode:  238 reward 200.00
# episode:  239 reward 200.00
# episode:  240 reward 104.00
# episode:  241 reward 137.00
# episode:  242 reward 200.00
# episode:  243 reward 59.00
# episode:  244 reward 93.00
# episode:  245 reward 200.00
# episode:  246 reward 178.00
# episode:  247 reward 185.00
# episode:  248 reward 200.00
# episode:  249 reward 200.00
# episode:  250 reward 143.00
# episode:  251 reward 200.00
# episode:  252 reward 90.00
# episode:  253 reward 110.00
# episode:  254 reward 200.00
# episode:  255 reward 200.00
# episode:  256 reward 123.00
# episode:  257 reward 140.00
# episode:  258 reward 101.00
# episode:  259 reward 174.00
# episode:  260 reward 148.00
# episode:  261 reward 139.00
# episode:  262 reward 200.00
# episode:  263 reward 200.00
# episode:  264 reward 200.00
# episode:  265 reward 150.00
# episode:  266 reward 200.00
# episode:  267 reward 120.00
# episode:  268 reward 200.00
# episode:  269 reward 154.00
# episode:  270 reward 166.00
# episode:  271 reward 122.00
# episode:  272 reward 193.00
# episode:  273 reward 47.00
# episode:  274 reward 200.00
# episode:  275 reward 115.00
# episode:  276 reward 110.00
# episode:  277 reward 69.00
# episode:  278 reward 167.00
# episode:  279 reward 123.00
# episode:  280 reward 200.00
# episode:  281 reward 200.00
# episode:  282 reward 200.00
# episode:  283 reward 200.00
# episode:  284 reward 136.00
# episode:  285 reward 200.00
# episode:  286 reward 200.00
# episode:  287 reward 122.00
# episode:  288 reward 170.00
# episode:  289 reward 200.00
# episode:  290 reward 200.00
# episode:  291 reward 127.00
# episode:  292 reward 200.00
# episode:  293 reward 200.00
# episode:  294 reward 200.00
# episode:  295 reward 200.00
# episode:  296 reward 200.00
# episode:  297 reward 193.00
# episode:  298 reward 194.00
# episode:  299 reward 200.00
# episode:  300 reward 165.00
# episode:  301 reward 151.00
# episode:  302 reward 135.00
# episode:  303 reward 182.00
# episode:  304 reward 200.00
# episode:  305 reward 200.00
# episode:  306 reward 200.00
# episode:  307 reward 168.00
# episode:  308 reward 198.00
# episode:  309 reward 167.00
# episode:  310 reward 176.00
# episode:  311 reward 200.00
# episode:  312 reward 137.00
# episode:  313 reward 156.00
# episode:  314 reward 200.00
# episode:  315 reward 190.00
# episode:  316 reward 152.00
# episode:  317 reward 124.00
# episode:  318 reward 176.00
# episode:  319 reward 153.00
# episode:  320 reward 193.00
# episode:  321 reward 165.00
# episode:  322 reward 88.00
# episode:  323 reward 124.00
# episode:  324 reward 102.00
# episode:  325 reward 88.00
# episode:  326 reward 128.00
# episode:  327 reward 117.00
# episode:  328 reward 165.00
# episode:  329 reward 158.00
# episode:  330 reward 200.00
# episode:  331 reward 200.00
# episode:  332 reward 200.00
# episode:  333 reward 121.00
# episode:  334 reward 200.00
# episode:  335 reward 200.00
# episode:  336 reward 190.00
# episode:  337 reward 200.00
# episode:  338 reward 200.00
# episode:  339 reward 200.00
# episode:  340 reward 200.00
# episode:  341 reward 200.00
# episode:  342 reward 187.00
# episode:  343 reward 200.00
# episode:  344 reward 200.00
# episode:  345 reward 142.00
# episode:  346 reward 200.00
# episode:  347 reward 200.00
# episode:  348 reward 133.00
# episode:  349 reward 123.00
# episode:  350 reward 197.00
# episode:  351 reward 200.00
# episode:  352 reward 200.00
# episode:  353 reward 200.00
# episode:  354 reward 200.00
# episode:  355 reward 155.00
# episode:  356 reward 173.00
# episode:  357 reward 200.00
# episode:  358 reward 181.00
# episode:  359 reward 200.00
# episode:  360 reward 122.00
# episode:  361 reward 200.00
# episode:  362 reward 200.00
# episode:  363 reward 174.00
# episode:  364 reward 162.00
# episode:  365 reward 200.00
# episode:  366 reward 200.00
# episode:  367 reward 147.00
# episode:  368 reward 151.00
# episode:  369 reward 200.00
# episode:  370 reward 200.00
# episode:  371 reward 168.00
# episode:  372 reward 200.00
# episode:  373 reward 146.00
# episode:  374 reward 187.00
# episode:  375 reward 165.00
# episode:  376 reward 200.00
# episode:  377 reward 170.00
# episode:  378 reward 200.00
# episode:  379 reward 155.00
# episode:  380 reward 183.00
# episode:  381 reward 200.00
# episode:  382 reward 200.00
# episode:  383 reward 137.00
# episode:  384 reward 200.00
# episode:  385 reward 192.00
# episode:  386 reward 159.00
# episode:  387 reward 200.00
# episode:  388 reward 200.00
# episode:  389 reward 200.00
# episode:  390 reward 200.00
# episode:  391 reward 200.00
# episode:  392 reward 200.00
# episode:  393 reward 179.00
# episode:  394 reward 200.00
# episode:  395 reward 200.00
# episode:  396 reward 200.00
# episode:  397 reward 200.00
# episode:  398 reward 200.00
# episode:  399 reward 200.00
# episode:  400 reward 200.00
# episode:  401 reward 136.00
# episode:  402 reward 200.00
# episode:  403 reward 200.00
# episode:  404 reward 200.00
# episode:  405 reward 200.00
# episode:  406 reward 200.00
# episode:  407 reward 200.00
# episode:  408 reward 191.00
# episode:  409 reward 134.00
# episode:  410 reward 145.00
# episode:  411 reward 191.00
# episode:  412 reward 127.00
# episode:  413 reward 191.00
# episode:  414 reward 181.00
# episode:  415 reward 162.00
# episode:  416 reward 145.00
# episode:  417 reward 132.00
# episode:  418 reward 137.00
# episode:  419 reward 139.00
# episode:  420 reward 157.00
# episode:  421 reward 110.00
# episode:  422 reward 74.00
# episode:  423 reward 126.00
# episode:  424 reward 103.00
# episode:  425 reward 197.00
# episode:  426 reward 200.00
# episode:  427 reward 200.00
# episode:  428 reward 200.00
# episode:  429 reward 148.00
# episode:  430 reward 138.00
# episode:  431 reward 188.00
# episode:  432 reward 157.00
# episode:  433 reward 200.00
# episode:  434 reward 180.00
# episode:  435 reward 152.00
# episode:  436 reward 200.00
# episode:  437 reward 167.00
# episode:  438 reward 200.00
# episode:  439 reward 161.00
# episode:  440 reward 200.00
# episode:  441 reward 171.00
# episode:  442 reward 174.00
# episode:  443 reward 200.00
# episode:  444 reward 200.00
# episode:  445 reward 200.00
# episode:  446 reward 165.00
# episode:  447 reward 200.00
# episode:  448 reward 129.00
# episode:  449 reward 134.00
# episode:  450 reward 200.00
# episode:  451 reward 195.00
# episode:  452 reward 200.00
# episode:  453 reward 200.00
# episode:  454 reward 197.00
# episode:  455 reward 200.00
# episode:  456 reward 170.00
# episode:  457 reward 200.00
# episode:  458 reward 176.00
# episode:  459 reward 187.00
# episode:  460 reward 200.00
# episode:  461 reward 200.00
# episode:  462 reward 200.00
# episode:  463 reward 197.00
# episode:  464 reward 200.00
# episode:  465 reward 200.00
# episode:  466 reward 200.00
# episode:  467 reward 200.00
# episode:  468 reward 200.00
# episode:  469 reward 200.00
# episode:  470 reward 200.00
# episode:  471 reward 200.00
# episode:  472 reward 200.00
# episode:  473 reward 200.00
# episode:  474 reward 184.00
# episode:  475 reward 200.00
# episode:  476 reward 200.00
# episode:  477 reward 200.00
# episode:  478 reward 200.00
# episode:  479 reward 200.00
# episode:  480 reward 200.00
# episode:  481 reward 200.00
# episode:  482 reward 200.00
# episode:  483 reward 200.00
# episode:  484 reward 200.00
# episode:  485 reward 200.00
# episode:  486 reward 200.00
# episode:  487 reward 200.00
# episode:  488 reward 200.00
# episode:  489 reward 200.00
# episode:  490 reward 200.00
# episode:  491 reward 200.00
# episode:  492 reward 200.00
# episode:  493 reward 200.00
# episode:  494 reward 200.00
# episode:  495 reward 200.00
# episode:  496 reward 200.00
# episode:  497 reward 200.00
# episode:  498 reward 192.00
# episode:  499 reward 200.00
# episode:  500 reward 200.00
# episode:  501 reward 200.00
# episode:  502 reward 200.00
# episode:  503 reward 200.00
# episode:  504 reward 200.00
# episode:  505 reward 200.00
# episode:  506 reward 200.00
# episode:  507 reward 184.00
# episode:  508 reward 200.00
# episode:  509 reward 200.00
# episode:  510 reward 200.00
# episode:  511 reward 200.00
# episode:  512 reward 200.00
# episode:  513 reward 153.00
# episode:  514 reward 200.00
# episode:  515 reward 200.00
# episode:  516 reward 200.00
# episode:  517 reward 200.00
# episode:  518 reward 200.00
# episode:  519 reward 171.00
# episode:  520 reward 194.00
# episode:  521 reward 199.00
# episode:  522 reward 167.00
# episode:  523 reward 200.00
# episode:  524 reward 200.00
# episode:  525 reward 200.00
# episode:  526 reward 200.00
# episode:  527 reward 200.00
# episode:  528 reward 200.00
# episode:  529 reward 200.00
# episode:  530 reward 200.00
# episode:  531 reward 200.00
# episode:  532 reward 200.00
# episode:  533 reward 200.00
# episode:  534 reward 200.00
# episode:  535 reward 200.00
# episode:  536 reward 200.00
# episode:  537 reward 200.00
# episode:  538 reward 200.00
# episode:  539 reward 200.00
# episode:  540 reward 200.00
# episode:  541 reward 165.00
# episode:  542 reward 200.00
# episode:  543 reward 200.00
# episode:  544 reward 200.00
# episode:  545 reward 200.00
# episode:  546 reward 200.00
# episode:  547 reward 200.00
# episode:  548 reward 199.00
# episode:  549 reward 200.00
# episode:  550 reward 200.00
# episode:  551 reward 200.00
# episode:  552 reward 200.00
# episode:  553 reward 200.00
# episode:  554 reward 200.00
# episode:  555 reward 200.00
# episode:  556 reward 200.00
# episode:  557 reward 200.00
# episode:  558 reward 200.00
# episode:  559 reward 200.00
# episode:  560 reward 200.00
# episode:  561 reward 200.00
# episode:  562 reward 200.00
# episode:  563 reward 200.00
# episode:  564 reward 200.00
# episode:  565 reward 200.00
# episode:  566 reward 200.00
# episode:  567 reward 200.00
# episode:  568 reward 200.00
# episode:  569 reward 200.00
# episode:  570 reward 200.00
# episode:  571 reward 200.00
# episode:  572 reward 200.00
# episode:  573 reward 200.00
# episode:  574 reward 200.00
# episode:  575 reward 200.00
# episode:  576 reward 200.00
# episode:  577 reward 178.00
# episode:  578 reward 200.00
# episode:  579 reward 200.00
# episode:  580 reward 199.00
# episode:  581 reward 200.00
# episode:  582 reward 200.00
# episode:  583 reward 200.00
# episode:  584 reward 200.00
# episode:  585 reward 185.00
# episode:  586 reward 200.00
# episode:  587 reward 200.00
# episode:  588 reward 141.00
# episode:  589 reward 200.00
# episode:  590 reward 200.00
# episode:  591 reward 200.00
# episode:  592 reward 200.00
# episode:  593 reward 200.00
# episode:  594 reward 165.00
# episode:  595 reward 200.00
# episode:  596 reward 200.00
# episode:  597 reward 200.00
# episode:  598 reward 200.00
# episode:  599 reward 200.00
# episode:  600 reward 200.00
# episode:  601 reward 169.00
# episode:  602 reward 200.00
# episode:  603 reward 200.00
# episode:  604 reward 200.00
# episode:  605 reward 154.00
# episode:  606 reward 200.00
# episode:  607 reward 200.00
# episode:  608 reward 200.00
# episode:  609 reward 200.00
# episode:  610 reward 200.00
# episode:  611 reward 200.00
# episode:  612 reward 164.00
# episode:  613 reward 138.00
# episode:  614 reward 167.00
# episode:  615 reward 163.00
# episode:  616 reward 136.00
# episode:  617 reward 122.00
# episode:  618 reward 166.00
# episode:  619 reward 138.00
# episode:  620 reward 200.00
# episode:  621 reward 175.00
# episode:  622 reward 200.00
# episode:  623 reward 200.00
# episode:  624 reward 143.00
# episode:  625 reward 130.00
# episode:  626 reward 200.00
# episode:  627 reward 146.00
# episode:  628 reward 159.00
# episode:  629 reward 200.00
# episode:  630 reward 114.00
# episode:  631 reward 170.00
# episode:  632 reward 162.00
# episode:  633 reward 160.00
# episode:  634 reward 166.00
# episode:  635 reward 200.00
# episode:  636 reward 200.00
# episode:  637 reward 166.00
# episode:  638 reward 160.00
# episode:  639 reward 127.00
# episode:  640 reward 161.00
# episode:  641 reward 200.00
# episode:  642 reward 200.00
# episode:  643 reward 159.00
# episode:  644 reward 157.00
# episode:  645 reward 200.00
# episode:  646 reward 177.00
# episode:  647 reward 200.00
# episode:  648 reward 200.00
# episode:  649 reward 200.00
# episode:  650 reward 200.00
# episode:  651 reward 194.00
# episode:  652 reward 200.00
# episode:  653 reward 200.00
# episode:  654 reward 200.00
# episode:  655 reward 200.00
# episode:  656 reward 200.00
# episode:  657 reward 200.00
# episode:  658 reward 200.00
# episode:  659 reward 183.00
# episode:  660 reward 200.00
# episode:  661 reward 200.00
# episode:  662 reward 200.00
# episode:  663 reward 200.00
# episode:  664 reward 200.00
# episode:  665 reward 200.00
# episode:  666 reward 200.00
# episode:  667 reward 200.00
# episode:  668 reward 200.00
# episode:  669 reward 200.00
# episode:  670 reward 200.00
# episode:  671 reward 200.00
# episode:  672 reward 200.00
# episode:  673 reward 200.00
# episode:  674 reward 200.00
# episode:  675 reward 200.00
# episode:  676 reward 200.00
# episode:  677 reward 200.00
# episode:  678 reward 200.00
# episode:  679 reward 200.00
# episode:  680 reward 200.00
# episode:  681 reward 200.00
# episode:  682 reward 200.00
# episode:  683 reward 200.00
# episode:  684 reward 200.00
# episode:  685 reward 192.00
# episode:  686 reward 200.00
# episode:  687 reward 200.00
# episode:  688 reward 200.00
# episode:  689 reward 200.00
# episode:  690 reward 200.00
# episode:  691 reward 200.00
# episode:  692 reward 186.00
# episode:  693 reward 200.00
# episode:  694 reward 200.00
# episode:  695 reward 200.00
# episode:  696 reward 200.00
# episode:  697 reward 191.00
# episode:  698 reward 200.00
# episode:  699 reward 142.00
# episode:  700 reward 198.00
# episode:  701 reward 200.00
# episode:  702 reward 176.00
# episode:  703 reward 197.00
# episode:  704 reward 146.00
# episode:  705 reward 200.00
# episode:  706 reward 134.00
# episode:  707 reward 148.00
# episode:  708 reward 157.00
# episode:  709 reward 176.00
# episode:  710 reward 136.00
# episode:  711 reward 81.00
# episode:  712 reward 121.00
# episode:  713 reward 113.00
# episode:  714 reward 129.00
# episode:  715 reward 121.00
# episode:  716 reward 135.00
# episode:  717 reward 164.00
# episode:  718 reward 140.00
# episode:  719 reward 127.00
# episode:  720 reward 128.00
# episode:  721 reward 162.00
# episode:  722 reward 158.00
# episode:  723 reward 138.00
# episode:  724 reward 148.00
# episode:  725 reward 148.00
# episode:  726 reward 162.00
# episode:  727 reward 164.00
# episode:  728 reward 149.00
# episode:  729 reward 168.00
# episode:  730 reward 161.00
# episode:  731 reward 155.00
# episode:  732 reward 196.00
# episode:  733 reward 139.00
# episode:  734 reward 188.00
# episode:  735 reward 200.00
# episode:  736 reward 200.00
# episode:  737 reward 200.00
# episode:  738 reward 175.00
# episode:  739 reward 200.00
# episode:  740 reward 200.00
# episode:  741 reward 200.00
# episode:  742 reward 200.00
# episode:  743 reward 200.00
# episode:  744 reward 200.00
# episode:  745 reward 200.00
# episode:  746 reward 200.00
# episode:  747 reward 200.00
# episode:  748 reward 200.00
# episode:  749 reward 200.00
# episode:  750 reward 200.00
# episode:  751 reward 200.00
# episode:  752 reward 200.00
# episode:  753 reward 200.00
# episode:  754 reward 200.00
# episode:  755 reward 200.00
# episode:  756 reward 200.00
# episode:  757 reward 200.00
# episode:  758 reward 200.00
# episode:  759 reward 200.00
# episode:  760 reward 200.00
# episode:  761 reward 200.00
# episode:  762 reward 200.00
# episode:  763 reward 200.00
# episode:  764 reward 200.00
# episode:  765 reward 200.00
# episode:  766 reward 200.00
# episode:  767 reward 200.00
# episode:  768 reward 200.00
# episode:  769 reward 200.00
# episode:  770 reward 200.00
# episode:  771 reward 200.00
# episode:  772 reward 200.00
# episode:  773 reward 185.00
# episode:  774 reward 200.00
# episode:  775 reward 200.00
# episode:  776 reward 200.00
# episode:  777 reward 200.00
# episode:  778 reward 200.00
# episode:  779 reward 200.00
# episode:  780 reward 200.00
# episode:  781 reward 200.00
# episode:  782 reward 181.00
# episode:  783 reward 200.00
# episode:  784 reward 200.00
# episode:  785 reward 200.00
# episode:  786 reward 200.00
# episode:  787 reward 200.00
# episode:  788 reward 200.00
# episode:  789 reward 138.00
# episode:  790 reward 200.00
# episode:  791 reward 200.00
# episode:  792 reward 200.00
# episode:  793 reward 200.00
# episode:  794 reward 200.00
# episode:  795 reward 200.00
# episode:  796 reward 200.00
# episode:  797 reward 200.00
# episode:  798 reward 200.00
# episode:  799 reward 200.00
# episode:  800 reward 200.00
# episode:  801 reward 200.00
# episode:  802 reward 200.00
# episode:  803 reward 200.00
# episode:  804 reward 200.00
# episode:  805 reward 200.00
# episode:  806 reward 200.00
# episode:  807 reward 200.00
# episode:  808 reward 200.00
# episode:  809 reward 200.00
# episode:  810 reward 200.00
# episode:  811 reward 200.00
# episode:  812 reward 200.00
# episode:  813 reward 200.00
# episode:  814 reward 200.00
# episode:  815 reward 200.00
# episode:  816 reward 200.00
# episode:  817 reward 200.00
# episode:  818 reward 200.00
# episode:  819 reward 200.00
# episode:  820 reward 200.00
# episode:  821 reward 200.00
# episode:  822 reward 200.00
# episode:  823 reward 200.00
# episode:  824 reward 200.00
# episode:  825 reward 200.00
# episode:  826 reward 200.00
# episode:  827 reward 200.00
# episode:  828 reward 200.00
# episode:  829 reward 200.00
# episode:  830 reward 200.00
# episode:  831 reward 200.00
# episode:  832 reward 200.00
# episode:  833 reward 200.00
# episode:  834 reward 200.00
# episode:  835 reward 200.00
# episode:  836 reward 200.00
# episode:  837 reward 200.00
# episode:  838 reward 200.00
# episode:  839 reward 200.00
# episode:  840 reward 200.00
# episode:  841 reward 200.00
# episode:  842 reward 200.00
# episode:  843 reward 200.00
# episode:  844 reward 200.00
# episode:  845 reward 200.00
# episode:  846 reward 200.00
# episode:  847 reward 200.00
# episode:  848 reward 200.00
# episode:  849 reward 200.00
# episode:  850 reward 200.00
# episode:  851 reward 200.00
# episode:  852 reward 200.00
# episode:  853 reward 200.00
# episode:  854 reward 200.00
# episode:  855 reward 200.00
# episode:  856 reward 200.00
# episode:  857 reward 200.00
# episode:  858 reward 200.00
# episode:  859 reward 200.00
# episode:  860 reward 200.00
# episode:  861 reward 200.00
# episode:  862 reward 200.00
# episode:  863 reward 200.00
# episode:  864 reward 200.00
# episode:  865 reward 200.00
# episode:  866 reward 200.00
# episode:  867 reward 200.00
# episode:  868 reward 200.00
# episode:  869 reward 200.00
# episode:  870 reward 200.00
# episode:  871 reward 200.00
# episode:  872 reward 200.00
# episode:  873 reward 200.00
# episode:  874 reward 200.00
# episode:  875 reward 200.00
# episode:  876 reward 200.00
# episode:  877 reward 200.00
# episode:  878 reward 200.00
# episode:  879 reward 200.00
# episode:  880 reward 200.00
# episode:  881 reward 200.00
# episode:  882 reward 200.00
# episode:  883 reward 200.00
# episode:  884 reward 200.00
# episode:  885 reward 200.00
# episode:  886 reward 200.00
# episode:  887 reward 200.00
# episode:  888 reward 200.00
# episode:  889 reward 200.00
# episode:  890 reward 200.00
# episode:  891 reward 200.00
# episode:  892 reward 200.00
# episode:  893 reward 200.00
# episode:  894 reward 200.00
# episode:  895 reward 200.00
# episode:  896 reward 200.00
# episode:  897 reward 200.00
# episode:  898 reward 200.00
# episode:  899 reward 200.00
# episode:  900 reward 200.00
# episode:  901 reward 200.00
# episode:  902 reward 200.00
# episode:  903 reward 200.00
# episode:  904 reward 200.00
# episode:  905 reward 200.00
# episode:  906 reward 200.00
# episode:  907 reward 200.00
# episode:  908 reward 200.00
# episode:  909 reward 200.00
# episode:  910 reward 200.00
# episode:  911 reward 200.00
# episode:  912 reward 200.00
# episode:  913 reward 200.00
# episode:  914 reward 200.00
# episode:  915 reward 200.00
# episode:  916 reward 200.00
# episode:  917 reward 200.00
# episode:  918 reward 200.00
# episode:  919 reward 200.00
# episode:  920 reward 200.00
# episode:  921 reward 200.00
# episode:  922 reward 200.00
# episode:  923 reward 200.00
# episode:  924 reward 200.00
# episode:  925 reward 200.00
# episode:  926 reward 200.00
# episode:  927 reward 200.00
# episode:  928 reward 200.00
# episode:  929 reward 200.00
# episode:  930 reward 200.00
# episode:  931 reward 200.00
# episode:  932 reward 200.00
# episode:  933 reward 200.00
# episode:  934 reward 200.00
# episode:  935 reward 175.00
# episode:  936 reward 200.00
# episode:  937 reward 200.00
# episode:  938 reward 200.00
# episode:  939 reward 200.00
# episode:  940 reward 200.00
# episode:  941 reward 200.00
# episode:  942 reward 200.00
# episode:  943 reward 200.00
# episode:  944 reward 200.00
# episode:  945 reward 200.00
# episode:  946 reward 200.00
# episode:  947 reward 200.00
# episode:  948 reward 200.00
# episode:  949 reward 200.00
# episode:  950 reward 200.00
# episode:  951 reward 200.00
# episode:  952 reward 200.00
# episode:  953 reward 200.00
# episode:  954 reward 200.00
# episode:  955 reward 200.00
# episode:  956 reward 200.00
# episode:  957 reward 200.00
# episode:  958 reward 200.00
# episode:  959 reward 200.00
# episode:  960 reward 200.00
# episode:  961 reward 200.00
# episode:  962 reward 200.00
# episode:  963 reward 200.00
# episode:  964 reward 200.00
# episode:  965 reward 200.00
# episode:  966 reward 200.00
# episode:  967 reward 200.00
# episode:  968 reward 200.00
# episode:  969 reward 200.00
# episode:  970 reward 200.00
# episode:  971 reward 200.00
# episode:  972 reward 200.00
# episode:  973 reward 200.00
# episode:  974 reward 200.00
# episode:  975 reward 200.00
# episode:  976 reward 200.00
# episode:  977 reward 200.00
# episode:  978 reward 200.00
# episode:  979 reward 200.00
# episode:  980 reward 200.00
# episode:  981 reward 200.00
# episode:  982 reward 200.00
# episode:  983 reward 200.00
# episode:  984 reward 200.00
# episode:  985 reward 200.00
# episode:  986 reward 200.00
# episode:  987 reward 200.00
# episode:  988 reward 200.00
# episode:  989 reward 200.00
# episode:  990 reward 200.00
# episode:  991 reward 200.00
# episode:  992 reward 200.00
# episode:  993 reward 200.00
# episode:  994 reward 200.00
# episode:  995 reward 200.00
# episode:  996 reward 200.00
# episode:  997 reward 200.00
# episode:  998 reward 174.00
# episode:  999 reward 200.00

# %%
def test_env(vis=False):
    state = env.reset()
    if vis: env.render()
    done = False
    total_reward = 0
    while not done:
        state = torch.FloatTensor(state)
        X = Actor(state)
        probs=F.softmax(X)
        dist=Categorical(probs)
        next_state, reward, done, _ = env.step(dist.sample().item())
        state = next_state
        if vis: env.render()
        total_reward += reward
    return total_reward

# %%
test_env(True)
# Out:
# /home/iyer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /home/iyer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   if __name__ == '__main__':
# 200.0
